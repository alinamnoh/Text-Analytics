# %% [markdown]
# # Lab Assignment 1 by:
#     Noor Alina binti Mohd.Noh (SW01081436)
#     Auni Hazirah binti Zulkifli (SW01081433)

# %%
# import libraries
import re
import json
import requests
from datetime import datetime

# %%
# define variables that will be used
offset = 0 # to point to the start/end
reviews = [] # a reviews array to store the reviews

# %%
# get the URL for the product chosen
url = 'https://shopee.com.my/Crossbody-Bags-for-Women-Soft-Leather-Luxury-Handbags-Women-Bags-Designer-Female-Shoulder-Messenger-Bag-Totes-i.238433890.7752093894?sp_atk=50c16a8d-8b14-40ec-8655-3cf5e5aba91a&xptdk=50c16a8d-8b14-40ec-8655-3cf5e5aba91a'

# search particular patterns in URL using regular expression
r = re.search(r'i\.(\d+)\.(\d+)', url)

# conidtional statement if...else to know either shop_id and item_id exists in r to validate if the URL is valid or not
if r:
    shop_id, item_id = r.group(1), r.group(2)
else:
    print("Invalid URL")
    exit()

# %%
# fetch data from the URL and parse the JSON response to interact with its contents
# to also validate if the data is fetched successfully or not using conditional statement if...else
ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
response = requests.get(ratings_url)

if response.ok:
    data = response.json()
    print(data) 
else:
    print("Failed to fetch data.")
# Out:
# {'error': 0, 'error_msg': None, 'data': {'ratings': [{'orderid': 140166439270316, 'itemid': 7752093894, 'cmtid': 11793184930, 'ctime': 1687270774, 'rating': 1, 'userid': 136193155, 'shopid': 238433890, 'comment': 'Material:soft n looks like genuine leather.\nDurability:Good and seems last for quite sometimes.\n\nReceived on 19/6. Choose blue colour and looks beautiful. Like it very much. Thank you seller and delivery man.  Will buy other colour next time. 👍🏼👍🏼', 'rating_star': 5, 'status': 2, 'mtime': 1709120541, 'editable': 0, 'opt': 2, 'filter': 7, 'mentioned': [], 'is_hidden': False, 'can_follow_up': None, 'follow_up': None, 'submit_time': 0, 'author_username': 's*****i', 'author_portrait': '', 'author_shopid': 136191331, 'anonymous': True, 'images': ['my-11134103-7qul2-li8vqefflw069d', 'my-11134103-7qul4-li8vqeffnakmc7'], 'videos': [{'id': 'my-11110103-6jrnk-li8wb196eyjn12', 'cover': 'https://down-aka-sg.img.susercontent.com/my-11110103-23060-8vg8yngl7isv08', 'url': 'https://down-aka-sg.vod.susercontent.com/api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16000461687270567.mp4', 'duration': 9753, 'upload_time': None, 'mms_ext': '{"vid":"my-11110103-6jrnk-li8wb196eyjn12","biz":103,"duration":9753,"create_time":1687270558,"serviceID":2,"cover":"https://down-aka-sg.img.susercontent.com/my-11110103-23060-8vg8yngl7isv08","cover_list":null,"formats":[{"format":1600046,"defn":"V480P","profile":"MP4","path":"api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16000461687270567.mp4","url":"https://down-aka-sg.vod.susercontent.com/api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16000461687270567.mp4","width":480,"height":854,"bitrate":669130,"size":930771,"fps":25.10373,"duration":9770,"update_time":1687270572},{"format":1600005,"defn":"V640P","profile":"MP4","path":"api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16000051687270560.mp4","url":"https://down-aka-sg.vod.susercontent.com/api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16000051687270560.mp4","width":640,"height":1138,"bitrate":870888,"size":1176242,"fps":25.10373,"duration":9753,"update_time":1687270566}],"default_format":{"format":1600005,"defn":"V640P","profile":"MP4","path":"","url":"https://down-aka-sg.vod.susercontent.com/api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16000051687270560.mp4","width":640,"height":1138,"bitrate":870888,"size":1176242,"fps":25.10373,"duration":9753,"update_time":1687270566},"extend_formats":{"H265":[{"format":1600304,"defn":"V480P","profile":"MP4","path":"api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16003041687270567.mp4","url":"https://down-aka-sg.vod.susercontent.com/api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16003041687270567.mp4","width":480,"height":854,"bitrate":519296,"size":755310,"fps":25.10373,"duration":9753,"update_time":1687270577},{"format":1600308,"defn":"V640P","profile":"MP4","path":"api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16003081687270567.mp4","url":"https://down-aka-sg.vod.susercontent.com/api/v4/11110103/mms/my-11110103-6jrnk-li8wb196eyjn12.16003081687270567.mp4","width":640,"height":1138,"bitrate":742749,"size":1063675,"fps":25.10373,"duration":9753,"update_time":1687270582}]},"ab_test":"feature_SPVNomal:1;codec:H265;priority:default;feature_AIEnhance:0;feature_Nomal:1;"}', 'cover_image_id': 'sg-11134206-7qve3-li8wien41y6hcf', 'highlight': {'id': 'sg-11110160-6jrr7-li8wjta1yakgb9', 'cover': 'https://down-cvs-sg.vod.susercontent.com/c3/98934353/160/A3oyOThVAOQyv2QjEf4HACc.jpg', 'url': 'https://down-cvs-sg.vod.susercontent.com/c3/98934353/160/A3oyORV0AFTkvmQjEfwHACc.mp4', 'duration': None, 'upload_time': None, 'mms_ext': '{"vid":"sg-11110160-6jrr7-li8wjta1yakgb9","biz":103,"duration":0,"create_time":1687270968,"serviceID":6,"cover":"https://down-cvs-sg.vod.susercontent.com/c3/98934353/160/A3oyOThVAOQyv2QjEf4HACc.jpg","cover_list":null,"formats":[],"default_format":{"format":600001,"defn":"ORI","profile":"MP4","path":"","url":"https://down-cvs-sg.vod.suserconten ...

# %%
# loop until condition is met
offset = 0
while True:
    # set the limit to only 20 reviews
    ratings_url = f'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
    data = requests.get(ratings_url).json()
    
    # from the data fetched, for loop will iterate to every data to extract the author_username, ctime (and modified into appropriate date format) and comment
    for rating in data['data']['ratings']:
        reviewer = rating['author_username']
        time = rating['ctime']
        modified_date = datetime.fromtimestamp(time).strftime('%Y-%m-%d')
        content = rating['comment']
    
        # append into reviews list
        reviews.append({
            'REVIEWER': reviewer,
            'DATE': modified_date,
            'CONTENT': content
        })
    # exit the loop if the length of the list (fetched data) is less than 20
    if len(data['data']['ratings']) < 20:
        break
    offset += 20

# %%
# print every data in reviews
for review in reviews:
    print("Reviewer: ", review['REVIEWER'])
    print("Date: ", review['DATE'])
    print("Content: ", review['CONTENT'])
    print()
# Out:
# Reviewer:  s*****i
# Date:  2023-06-20
# Content:  Material:soft n looks like genuine leather.
# Durability:Good and seems last for quite sometimes.
#
# Received on 19/6. Choose blue colour and looks beautiful. Like it very much. Thank you seller and delivery man.  Will buy other colour next time. 👍🏼👍🏼
#
# Reviewer:  batrisyiaed
# Date:  2023-07-13
# Content:  Durability:besar dan cantik
# Material:lembut
#
# Parcel dlm keadaan baik laju penghantran dr china ke sarawak.seller cepat buat keja beg yg cantik dan puas hati memang cantik  beg besar wrna pun cantik.beg nmpk mahal tak rugi membeli love sangat sangat😍😍😍😍😍😍😍👍👍👍👍👍👍terima kasih seller dan ABX
#
# Reviewer:  nadyalyj
# Date:  2022-12-25
# Content:  Material:leather like
# Durability:so far so good
#
# Delivery was fast and the package was packed nicely. the volume of the bag is huge, can stuff in a lot of things. Thank you seller
#
# Reviewer:  p*****n
# Date:  2024-01-09
# Content:  Durability:good
# Material:strong
#
# Well wrapped.. very nice..I just love the colour..many zips front and back.. suitable for carry many things.. thanks seller..
#
# Reviewer:  mohd_sidik
# Date:  2022-03-07
# Content:  Sampai dengan selamat.... Kualiti setanding harga... Cantik dan besar .... Terima kasih
#
# Reviewer:  girl8910
# Date:  2021-10-03
# Content:  Nice color, not too red, delivery takes about 10 to 14 days, except for the strong smell, the beg is just nice for me.
#
# Reviewer:  e......s
# Date:  2023-12-25
# Content:  Durability:ok
# Material:ok
#
# Item safely received..
# bought for my mom
# Material ok..soft texture
# Hopefully will last longer
# Tq
#
# Reviewer:  wany_iman
# Date:  2021-10-04
# Content:  Fast delivery .
# Gambar nampak macam kecik. Tapi besar rupanya. Banyak compartment . Sesuai la untuk mak2.. banyak barang boleh letak..
#
# Reviewer:  sharmi1203
# Date:  2021-10-29
# Content:  The bag is big n comes with few compartments… convenient to carry lots of things BUT IT IS VERY SMELLY…like fish! Even my family members said they can smell it! I sprayed perfume, air freshener but still smelly!
#
# Reviewer:  chaplee
# Date:  2022-10-02
# Content:  Material is soft and good quality but a bite too big.Thanks seller.
#
# Reviewer:  isyang8587
# Date:  2021-09-29
# Content:  Good productivity.... Good value for money.. Fast delivery... Recommend to others.... Good good good... ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
#
# Reviewer:  zarina1964
# Date:  2024-01-14
# Content:  Penghantaran laju juga walaupun dari China..material pn ok n handbag ni besar, sesuai untuk isi berbagai brg. Tq seller
#
# Reviewer:  d*****4
# Date:  2024-01-06
# Content:  Durability:Sesuai
# Material:Halus dan lembut
#
# Beg besar boleh letak barang banyak
#
# Reviewer:  aqeefrayhan
# Date:  2023-02-09
# Content:  Material:ok baik
# Durability:cantek
#
# cantek n nampak mahal hihi..beli utk wife harap wife suke
#
# Reviewer:  fauziahkamarun
# Date:  2021-03-29
# Content:  Tq seller 👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼👍🏼develery very fast🌟🌟🌟🌟🌟🌟🌟🌟🌟
#
# Reviewer:  a*****h
# Date:  2021-11-27
# Content:  Fasttt deliveryyy
# Gooood product qualityy
# Goood valuee for moneyyy
#
# Reviewer:  z*****e
# Date:  2022-03-04
# Content:  Beg ni cantik sgt22.. Tp die besa ckit dpd yg ditunjukkan dkt dlm gmba..
#
# Reviewer:  ckplkgeok
# Date:  2023-01-28
# Content:  Product received in good condition. Packed nicely.very Fast delivery
#
# Reviewer:  suesurina76
# Date:  2022-08-03
# Content:  Barang sampai dengan baik ..
#
# Reviewer:  jonimolla
# Date:  2021-03-12
# Content:   very nicely received my order
#
# Reviewer:  lalaaaa_mrs
# Date:  2021-10-14
# Content:  Good quality, fast delivery. Thankk youuuuu. Will buy again
#
# Reviewer:  jnsjns1972
# Date:  2023-02-24
# Content:  Beg besar memenuhi cita rasa saya...saya suka🥰
#
# Reviewer:  cikadlin
# Date:  2021-12-04
# Content:  Dah sampai seriuos cakap . Memang cantikk the best lah . takda rosak apa2 semua okey . padan dengan harga . cantik cantikk . suka sangat 😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍
#
# Reviewer:  kokpeng12
# Date:  2022-11-28
# Content:  product received in good condition。packed nicely。fast delivery
#
# Reviewer:  galalima
# Date:  2023-09-09
# Content:  Durability:terbaik
# Material:seperti dlm gmbr cantik
#
# Reviewer:  haz1qah
# Date:  2021-11-16
# Content:  Rate untuk coins saja.
# Barang semua ok.
# Tolong belikan untuk ibu di kampung.
# Tq seller.
# Tq courier.
# Tq shopee.
#
# Reviewer:  h*****6
# Date:  2022-10-18
# Content:  Bag cantik..
# Besar elok ..
# Puas hati
# Thank you
# Sory pic & video not available 😆
#
# Reviewer:  b*****h
# Date:  2023-09-05
# Content:  Material:kulit
#
# Warna terlalu gelap drpd gmbr😭😭☝🏻 tapi it's okayy harap ibu aq terima seadanya
#
# Reviewer:  r*****8
# Date:  2021-10-15
# Content:  very recomended ... ver very very nice and beautiful bag...tq so much seller
#
# Reviewer:  rayner477
# Date:  2021-10-14
# Content:  RM0 Sentiasa berhati-hati dan peka akan tempat yang anda kunjungi. Jangan bawa balik Covid-19 ke rumah anda. Ingatlah orang yang anda sayangi.
#
# Reviewer:  linahmarali
# Date:  2022-03-20
# Content:  Terbaik
# Nanti beli lagi
# Cepat juga lh walaupun dari cina
#
# Reviewer:  zarinazohri
# Date:  2023-03-10
# Content:  Puas hati...besar n byk partition...rekomen
#
# Reviewer:  azianjamil123
# Date:  2023-02-20
# Content:  Penghantaran cepat..bungkusan yg elok..t.q
#
# Reviewer:  j*****5
# Date:  2022-07-23
# Content:
#
# Reviewer:  n*****3
# Date:  2022-03-26
# Content:  Barang telah diterima terima kasih saller n jnt boleh repeat order next time
#
# Reviewer:  hafizahalias809
# Date:  2024-01-21
# Content:  Material:beg tangan wanita..okey je.. padanan ngan harga
# Durability:sesuai jugok lah ngan wanita yang berumur 40 an
#
# Perkhidmatan penghantaran percuma dan selamat
#
# Reviewer:  zaleha2507
# Date:  2023-08-21
# Content:  Material:Warna beg  dan kualiti amat baik.
# Durability:Beg ini amat besar memang sesuai dengan wanita seperti saya yang suka bawa banysk barang.
#
# Reviewer:  r*****a
# Date:  2024-03-29
# Content:  Durability:Nice materials.. Vslue for our money
#
# Worth buying guys.... Very cheap.. Affordable indeed. 👌👍
#
# Reviewer:  m67jte_fiy
# Date:  2021-12-08
# Content:  As seen in the picture
#
# Reviewer:  yanz2705
# Date:  2022-04-27
# Content:  Satisfied. Tq
#
# Reviewer:  solehahali
# Date:  2024-02-22
# Content:  Durability:good
# Material:good
#
# Reviewer:  eb2021mm
# Date:  2023-12-21
# Content:  Material:✔️%Good material..
#
# Reviewer:  psm8959
# Date:  2023-09-22
# Content:  Material:good tqvm
#
# Reviewer:  jidinor
# Date:  2022-10-26
# Content:  nice..good quality
#
# Reviewer:  jenigka
# Date:  2022-12-01
# Content:  Material:great
#
# Reviewer:  leeburgerleeburger
# Date:  2024-03-20
# Content:  Durability:Good
#
# Reviewer:  a*****i
# Date:  2022-12-19
# Content:  Besar sikit dari expectation
#
# Reviewer:  4bdul_muiz
# Date:  2023-05-15
# Content:  Material:kulitnya lembut
#
# kulit lembut..
#
# Reviewer:  rozzaqistina
# Date:  2021-07-07
# Content:  ok la,bag besar..
#
# Reviewer:  cindycyen
# Date:  2021-12-16
# Content:  Tq seller
#
# Reviewer:  ling0202li0707
# Date:  2021-04-20
# Content:  够大 质量也好👍🏻
#
# Reviewer:  rudisupar
# Date:  2021-11-22
# Content:  TerBaikk
#
# Reviewer:  e*****3
# Date:  2023-08-21
# Content:
#
# Reviewer:  arishakally2017
# Date:  2023-09-09
# Content:
#
# Reviewer:  noratikahkhairunasir
# Date:  2023-09-03
# Content:
#
# Reviewer:  fauziatulakmal
# Date:  2023-12-14
# Content:
#
# Reviewer:  kelly6034
# Date:  2024-01-16
# Content:
#
# Reviewer:  ngailinglaw
# Date:  2024-01-09
# Content:
#
# Reviewer:  jessiengow
# Date:  2024-01-20
# Content:
#
# Reviewer:  nozomik0182
# Date:  2024-01-28
# Content:
#
# Reviewer:  lizaoamar
# Date:  2024-02-13
# Content:
#
# Reviewer:  riezandin82
# Date:  2024-03-04
# Content:
#
# Reviewer:  h*****0
# Date:  2024-03-01
# Content:
#
# Reviewer:  cikpiya10
# Date:  2024-01-22
# Content:
#
# Reviewer:  rokayah74
# Date:  2024-02-11
# Content:
#
# Reviewer:  manismohamed
# Date:  2023-09-25
# Content:
#
# Reviewer:  ralynarshd99
# Date:  2024-03-20
# Content:
#
# Reviewer:  aprilgurlz24
# Date:  2023-09-30
# Content:
#
# Reviewer:  tsf1191
# Date:  2023-11-28
# Content:
#
# Reviewer:  lydiavoon
# Date:  2024-03-03
# Content:
#
# Reviewer:  sflowfmc
# Date:  2023-12-13
# Content:
#
# Reviewer:  zahariah12345
# Date:  2024-01-01
# Content:
#
# Reviewer:  ai_ling_tang
# Date:  2023-09-20
# Content:
#
# Reviewer:  hidayaroslan
# Date:  2024-01-18
# Content:
#
# Reviewer:  jennykhoo3833
# Date:  2024-01-19
# Content:
#
# Reviewer:  cloverleaf_123
# Date:  2023-08-21
# Content:
#
# Reviewer:  malja1967
# Date:  2024-03-04
# Content:
#
# Reviewer:  surwaniabdaziz
# Date:  2023-12-01
# Content:
#
# Reviewer:  hildaanthony
# Date:  2024-02-25
# Content:
#
# Reviewer:  s*****e
# Date:  2023-08-02
# Content:
#
# Reviewer:  pinkyhew
# Date:  2023-11-26
# Content:
#
# Reviewer:  khaty50
# Date:  2023-08-17
# Content:
#
# Reviewer:  rinafadhil115
# Date:  2023-08-27
# Content:
#
# Reviewer:  n*****n
# Date:  2023-12-25
# Content:
#
# Reviewer:  blenderfenny
# Date:  2024-02-05
# Content:
#
# Reviewer:  rosniwatiyeopisa
# Date:  2023-07-25
# Content:
#
# Reviewer:  azilahyusoff90
# Date:  2023-07-06
# Content:
#
# Reviewer:  martin_kc
# Date:  2023-07-04
# Content:
#
# Reviewer:  rosnahsharon
# Date:  2023-05-14
# Content:
#
# Reviewer:  johana24._
# Date:  2023-05-13
# Content:
#
# Reviewer:  burongoh
# Date:  2023-05-04
# Content:
#
# Reviewer:  suriantisaiful
# Date:  2023-05-03
# Content:
#
# Reviewer:  shafiai
# Date:  2023-05-11
# Content:
#
# Reviewer:  elsieafin
# Date:  2023-04-24
# Content:
#
# Reviewer:  azamaziz1978
# Date:  2023-03-18
# Content:
#
# Reviewer:  r*****8
# Date:  2023-03-07
# Content:
#
# Reviewer:  u*****a
# Date:  2023-02-27
# Content:
#
# Reviewer:  mohdnizamhjmusa
# Date:  2022-05-06
# Content:
#
# Reviewer:  mohdnizamhjmusa
# Date:  2021-08-26
# Content:
#
# Reviewer:  nazrimohammed
# Date:  2023-03-02
# Content:
#
# Reviewer:  nazriyati
# Date:  2023-01-16
# Content:
#
# Reviewer:  rosoliza
# Date:  2023-01-17
# Content:
#
# Reviewer:  aireengoh
# Date:  2023-01-09
# Content:
#
# Reviewer:  ceciliajustinrajang
# Date:  2022-10-17
# Content:
#
# Reviewer:  aria10.co
# Date:  2022-09-08
# Content:
#
# Reviewer:  fendeeshop
# Date:  2021-12-24
# Content:
#
# Reviewer:  norbaizura.shariff
# Date:  2022-04-18
# Content:
#
# Reviewer:  nyukmeeleong
# Date:  2022-06-11
# Content:
#
# Reviewer:  awiyah85
# Date:  2022-07-01
# Content:
#
# Reviewer:  angelapuyangangelz
# Date:  2022-07-15
# Content:
#
# Reviewer:  misiah1986
# Date:  2022-08-03
# Content:
#
# Reviewer:  bavanikalidasan
# Date:  2021-06-14
# Content:
#
# Reviewer:  senniaralasija
# Date:  2021-01-27
# Content:
#
# Reviewer:  anjuliesumbaanakradin
# Date:  2021-11-04
# Content:
#
# Reviewer:  nasyikin2
# Date:  2021-09-17
# Content:
#
# Reviewer:  k*****7
# Date:  2021-02-05
# Content:
#
# Reviewer:  misi_ain
# Date:  2021-01-15
# Content:
#
# Reviewer:  f*****2
# Date:  2021-11-02
# Content:
#
# Reviewer:  alwanibee
# Date:  2022-09-26
# Content:
#
# Reviewer:  nurazamri
# Date:  2022-08-27
# Content:
#
# Reviewer:  alice251277
# Date:  2021-10-17
# Content:
#
# Reviewer:  syafiqmawardi
# Date:  2021-10-08
# Content:
#
# Reviewer:  wendythang
# Date:  2022-09-24
# Content:
#
# Reviewer:  sutikaazmat
# Date:  2022-02-23
# Content:
#
# Reviewer:  ainaaairaizzara
# Date:  2021-12-12
# Content:
#
# Reviewer:  71ps4nc2za
# Date:  2023-02-02
# Content:
#
# Reviewer:  bondahumairah
# Date:  2022-07-29
# Content:
#
# Reviewer:  sem_88
# Date:  2022-04-28
# Content:
#
# Reviewer:  8grf91bmpt
# Date:  2021-10-18
# Content:
#
# Reviewer:  rajanorhafiza
# Date:  2022-07-14
# Content:
#
# Reviewer:  lisa.david
# Date:  2022-01-07
# Content:
#
# Reviewer:  0rei2a_aab
# Date:  2022-08-18
# Content:
#
# Reviewer:  56hasanah
# Date:  2021-07-01
# Content:
#
# Reviewer:  hariyatiabdamin
# Date:  2022-12-05
# Content:
#
# Reviewer:  diwfvyzld9
# Date:  2021-10-23
# Content:

# %%
# import csv library
import csv

# %%
# write the review into csv file named shoppeReviews
with open('shopeeReviews.csv', 'w', newline = '', encoding = 'utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames = ['REVIEWER', 'DATE', 'CONTENT'])
    writer.writeheader()
    writer.writerows(reviews)
    
print("Saved successfully into csv file")
# Out:
# Saved successfully into csv file
